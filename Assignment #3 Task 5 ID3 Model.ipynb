# %%
from sklearn import tree                                                        
from sklearn.metrics import precision_recall_fscore_support

decide = tree.DecisionTreeClassifier()

#Dates start at 7, increase by 7 each time.
#Each University has its own number, starting with 1 and increasing by 1 each time
#Home = 0, Away = 1
#In = 0, Out = 1
#"1-NBC" = 1, "4-ABC" = 2, "2-ESPN" = 3, "3-FOX" = 4, "5-CBS" = 5


#[date, university, where, top25, media]
X = [ [7, 1,0,1,1],                       #1                                                  
      [14,2,1,1,2],                       #2                                                   
      [21,3,0,0,1],                       #3                                                   
      [28,4,0,1,1],                       #4    
      [35,5,1,0,2],                       #5
      [42,6,0,1,1],                       #6                                                   
      [49,7,0,0,1],                       #7
      [56,8,1,1,2],                       #8
      [63,9,1,1,2],                       #9
      [70,10,0,1,1],                      #10
      [77,11,1,1,1],                      #11
      [84,12,1,0,4],                      #12
      [91,13,1,1,2],
      [98,14,0,1,1],
      [105,15,0,1,1],
      [112,16,0,1,1],
      [119,17,0,1,3],
      [126,18,1,1,2],
      [133,19,0,0,1],
      [140,20,0,1,1],
      [147,21,0,1,5],
      [154,22,0,1,1],
      [161,23,0,0,1],
      [168,24,1,0,2]]

#Label: Win/Lose
Y = ['Win', 'Win', 'Win',
     'Win', 'Lose', 'Win',
     'Win', 'Win', 'Win',
     'Win', 'Win', 'Lose',
     'Lose', 'Win', 'Lose',
     'Lose', 'Win', 'Lose',
     'Lose', 'Win', 'Lose',
     'Win', 'Lose', 'Lose']

#Dates start at 7, increase by 7 each time.
#Each University has its own number, starting with 1 and increasing by 1 each time
#Home = 0, Away = 1
#In = 0, Out = 1
#"1-NBC" = 1, "4-ABC" = 2, "2-ESPN" = 3, "3-FOX" = 4, "5-CBS" = 5

decide = decide.fit(X, Y)
result1 = decide.predict([[175,25,0,1,1]])  
result2 = decide.predict([[182,26,0,0,1]])  
result3 = decide.predict([[189,27,1,1,3]])  
result4 = decide.predict([[196,28,1,1,4]]) 
result5 = decide.predict([[203,29,0,1,1]])
result6 = decide.predict([[210,30,1,1,2]])
result7 = decide.predict([[217,31,0,0,1]])
result8 = decide.predict([[224,32,0,1,1]])
result9 = decide.predict([[231,33,0,1,1]])
result10= decide.predict([[238,34,1,0,2]])
result11= decide.predict([[245,35,0,1,1]])
result12= decide.predict([[252,36,1,0,2]])


print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
print(result9)
print(result10)
print(result11)
print(result12)

#Decision tree information
tree.plot_tree(decide)
# Out:
# ['Win']
# ['Lose']
# ['Lose']
# ['Lose']
# ['Win']
# ['Lose']
# ['Lose']
# ['Win']
# ['Win']
# ['Lose']
# ['Win']
# ['Lose']
# [Text(275.55555555555554, 343.2, 'X[1] <= 11.5\nentropy = 0.486\nsamples = 24\nvalue = [10, 14]'),
#  Text(165.33333333333334, 290.4, 'X[3] <= 0.5\nentropy = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(110.22222222222223, 237.59999999999997, 'X[4] <= 1.5\nentropy = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(55.111111111111114, 184.79999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(165.33333333333334, 184.79999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(220.44444444444446, 237.59999999999997, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(385.7777777777778, 290.4, 'X[2] <= 0.5\nentropy = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(330.6666666666667, 237.59999999999997, 'X[3] <= 0.5\nentropy = 0.494\nsamples = 9\nvalue = [5, 4]'),
# ...
