# %%
#Import math tools
import math

print("For Part 1:")
print(" ")
print("For each of the win coordinates:")
print(("X1  (3,5)"))
print(("X2  (3,4)"))
print(("X3  (2,8)"))
print(("X4  (2,3)"))
print(("X5  (6,2)"))
print(("X6  (6,4)"))
print(("X7  (7,3)"))
print(("X8  (7,4)"))
print(("X9  (8,5)"))
print(("X10 (7,6)"))


print(" ")
print(" ")
print(" ")
print(" ")


print("Part 1 Question 1:")
#Centroid 1: (4,6)
#Centroid 2: (5,4)

#Manhattan distance Kmeans
print ("Using the Manhattan distance metric: ")
#(3,5)
X1_1 = abs(3-4) + abs(5-6)#Centroid 1
X1_2 = abs(3-5) + abs(5-4)#Centroid 2

if X1_1 < X1_2:
    print ("X1 is closer to Centroid (4,6)")
else:
    print ("X1 is closer to Centroid (5,4)")

#(3,4)
X2_1 = abs(3-4) + abs(4-6)#Centroid 1
X2_2 = abs(3-5) + abs(4-4)#Centroid 2

if X2_1 < X2_2:
    print ("X2 is closer to Centroid (4,6)")
else:
    print ("X2 is closer to Centroid (5,4)")
    
#(2,8)
X3_1 = abs(2-4) + abs(8-6)#Centroid 1
X3_2 = abs(2-5) + abs(8-4)#Centroid 2

if X3_1 < X3_2:
    print ("X3 is closer to Centroid (4,6)")
else:
    print ("X3 is closer to Centroid (5,4)")

#(2,3)
X4_1 = abs(2-4) + abs(3-6)#Centroid 1
X4_2 = abs(2-5) + abs(3-4)#Centroid 2

if X4_1 < X4_2:
    print ("X4 is closer to Centroid (4,6)")
else:
    print ("X4 is closer to Centroid (5,4)")
    
#(6,2)
X5_1 = abs(6-4) + abs(2-6)#Centroid 1
X5_2 = abs(6-5) + abs(2-4)#Centroid 2

if X5_1 < X5_2:
    print ("X5 is closer to Centroid (4,6)")
else:
    print ("X5 is closer to Centroid (5,4)")

    
#(6,4)
X6_1 = abs(6-4) + abs(4-6)#Centroid 1
X6_2 = abs(6-5) + abs(4-4)#Centroid 2

if X6_1 < X6_2:
    print ("X6 is closer to Centroid (4,6)")
else:
    print ("X6 is closer to Centroid (5,4)")

    
#(7,3)
X7_1 = abs(7-4) + abs(3-6)#Centroid 1
X7_2 = abs(7-5) + abs(3-4)#Centroid 2

if X7_1 < X7_2:
    print ("X7 is closer to Centroid (4,6)")
else:
    print ("X7 is closer to Centroid (5,4)")  

    
#(7,4)
X8_1 = abs(7-4) + abs(4-6)#Centroid 1
X8_2 = abs(7-5) + abs(4-4)#Centroid 2

if X8_1 < X8_2:
    print ("X8 is closer to Centroid (4,6)")
else:
    print ("X8 is closer to Centroid (5,4)") 
    
#(8,5)
X9_1 = abs(8-4) + abs(5-6)#Centroid 1
X9_2 = abs(8-5) + abs(5-4)#Centroid 2

if X9_1 < X9_2:
    print ("X9 is closer to Centroid (4,6)")
else:
    print ("X9 is closer to Centroid (5,4)") 
    
#(7,6)
X10_1 = abs(7-4) + abs(6-6)#Centroid 1
X10_2 = abs(7-5) + abs(6-4)#Centroid 2

if X10_1 < X10_2:
    print ("X10 is closer to Centroid (4,6)")
else:
    print ("X10 is closer to Centroid (5,4)") 
    
print(" ")
print(" ")
print(" ")
print(" ")   





print("Part 1 Question 2:")

#Euclidian distance Kmeans

print ("Using the Euclidian distance metric: ")
#(3,5)
X1_1 = math.sqrt(((3-4)**2) + ((5-6)**2))#Centroid 1
X1_2 = math.sqrt(((3-5)**2) + ((5-4)**2))#Centroid 2

if X1_1 < X1_2:
    print ("X1 is closer to Centroid (4,6)")
else:
    print ("X1 is closer to Centroid (5,4)")

#(3,4)
X2_1 = math.sqrt(((3-4)**2) + ((4-6)**2))#Centroid 1
X2_2 = math.sqrt(((3-5)**2) + ((4-4)**2))#Centroid 2

if X2_1 < X2_2:
    print ("X2 is closer to Centroid (4,6)")
else:
    print ("X2 is closer to Centroid (5,4)")
    
#(2,8)
X3_1 = math.sqrt(((2-4)**2) + ((8-6)**2))#Centroid 1
X3_2 = math.sqrt(((2-5)**2) + ((8-4)**2))#Centroid 2

if X3_1 < X3_2:
    print ("X3 is closer to Centroid (4,6)")
else:
    print ("X3 is closer to Centroid (5,4)")

#(2,3)
X4_1 = math.sqrt(((2-4)**2) + ((3-6)**2))#Centroid 1
X4_2 = math.sqrt(((2-5)**2) + ((3-4)**2))#Centroid 2

if X4_1 < X4_2:
    print ("X4 is closer to Centroid (4,6)")
else:
    print ("X4 is closer to Centroid (5,4)")
    
#(6,2)
X5_1 = math.sqrt(((6-4)**2) + ((2-6)**2))#Centroid 1
X5_2 = math.sqrt(((6-5)**2) + ((2-4)**2))#Centroid 2

if X5_1 < X5_2:
    print ("X5 is closer to Centroid (4,6)")
else:
    print ("X5 is closer to Centroid (5,4)")

    
#(6,4)
X6_1 = math.sqrt(((6-4)**2) + ((4-6)**2))#Centroid 1
X6_2 = math.sqrt(((6-5)**2) + ((4-4)**2))#Centroid 2

if X6_1 < X6_2:
    print ("X6 is closer to Centroid (4,6)")
else:
    print ("X6 is closer to Centroid (5,4)")

    
#(7,3)
X7_1 = math.sqrt(((7-4)**2) + ((3-6)**2))#Centroid 1
X7_2 = math.sqrt(((7-5)**2) + ((3-4)**2))#Centroid 2

if X7_1 < X7_2:
    print ("X7 is closer to Centroid (4,6)")
else:
    print ("X7 is closer to Centroid (5,4)")  

    
#(7,4)
X8_1 = math.sqrt(((7-4)**2) + ((4-6)**2))#Centroid 1
X8_2 = math.sqrt(((7-5)**2) + ((4-4)**2))#Centroid 2

if X8_1 < X8_2:
    print ("X8 is closer to Centroid (4,6)")
else:
    print ("X8 is closer to Centroid (5,4)") 
    
#(8,5)
X9_1 = math.sqrt(((8-4)**2) + ((5-6)**2))#Centroid 1
X9_2 = math.sqrt(((8-5)**2) + ((5-4)**2))#Centroid 2

if X9_1 < X9_2:
    print ("X9 is closer to Centroid (4,6)")
else:
    print ("X9 is closer to Centroid (5,4)") 
    
#(7,6)
X10_1 = math.sqrt(((7-4)**2) + ((6-6)**2))#Centroid 1
X10_2 = math.sqrt(((7-5)**2) + ((6-4)**2))#Centroid 2

if X10_1 < X10_2:
    print ("X10 is closer to Centroid (4,6)")
else:
    print ("X10 is closer to Centroid (5,4)") 

    
    
    
print(" ")
print(" ")
print(" ")
print(" ")


print("Part 1 Question 3:")
#Centroid 1: (3,3)
#Centroid 2: (8,3)

#Manhattan distance Kmeans
print ("Using the Manhattan distance metric: ")
#(3,5)
X1_1 = abs(3-3) + abs(5-3)#Centroid 1
X1_2 = abs(3-8) + abs(5-3)#Centroid 2

if X1_1 < X1_2:
    print ("X1 is closer to Centroid (3,3)")
else:
    print ("X1 is closer to Centroid (8,3)")

#(3,4)
X2_1 = abs(3-3) + abs(4-3)#Centroid 1
X2_2 = abs(3-8) + abs(4-3)#Centroid 2

if X2_1 < X2_2:
    print ("X2 is closer to Centroid (3,3)")
else:
    print ("X2 is closer to Centroid (8,3)")
    
#(2,8)
X3_1 = abs(2-3) + abs(8-3)#Centroid 1
X3_2 = abs(2-8) + abs(8-3)#Centroid 2

if X3_1 < X3_2:
    print ("X3 is closer to Centroid (3,3)")
else:
    print ("X3 is closer to Centroid (8,3)")

#(2,3)
X4_1 = abs(2-3) + abs(3-3)#Centroid 1
X4_2 = abs(2-8) + abs(3-3)#Centroid 2

if X4_1 < X4_2:
    print ("X4 is closer to Centroid (3,3)")
else:
    print ("X4 is closer to Centroid (8,3)")
    
#(6,2)
X5_1 = abs(6-3) + abs(2-3)#Centroid 1
X5_2 = abs(6-8) + abs(2-3)#Centroid 2

if X5_1 < X5_2:
    print ("X5 is closer to Centroid (3,3)")
else:
    print ("X5 is closer to Centroid (8,3)")

    
#(6,4)
X6_1 = abs(6-3) + abs(4-3)#Centroid 1
X6_2 = abs(6-8) + abs(4-3)#Centroid 2

if X6_1 < X6_2:
    print ("X6 is closer to Centroid (3,3)")
else:
    print ("X6 is closer to Centroid (8,3)")

    
#(7,3)
X7_1 = abs(7-3) + abs(3-3)#Centroid 1
X7_2 = abs(7-8) + abs(3-3)#Centroid 2

if X7_1 < X7_2:
    print ("X7 is closer to Centroid (3,3)")
else:
    print ("X7 is closer to Centroid (8,3)")  

    
#(7,4)
X8_1 = abs(7-3) + abs(4-3)#Centroid 1
X8_2 = abs(7-8) + abs(4-3)#Centroid 2

if X8_1 < X8_2:
    print ("X8 is closer to Centroid (3,3)")
else:
    print ("X8 is closer to Centroid (8,3)") 
    
#(8,5)
X9_1 = abs(8-3) + abs(5-3)#Centroid 1
X9_2 = abs(8-8) + abs(5-3)#Centroid 2

if X9_1 < X9_2:
    print ("X9 is closer to Centroid (3,3)")
else:
    print ("X9 is closer to Centroid (8,3)") 
    
#(7,6)
X10_1 = abs(7-3) + abs(6-3)#Centroid 1
X10_2 = abs(7-8) + abs(6-3)#Centroid 2

if X10_1 < X10_2:
    print ("X10 is closer to Centroid (3,3)")
else:
    print ("X10 is closer to Centroid (8,3)")     
    

    
print(" ")
print(" ")
print(" ")
print(" ")


print("Part 1 Question 4:")
#Centroid 1: (3,2)
#Centroid 2: (4,8)

#Manhattan distance Kmeans
print ("Using the Manhattan distance metric: ")
#(3,5)
X1_1 = abs(3-3) + abs(5-2)#Centroid 1
X1_2 = abs(3-4) + abs(5-8)#Centroid 2

if X1_1 < X1_2:
    print ("X1 is closer to Centroid (3,2)")
else:
    print ("X1 is closer to Centroid (4,8)")

#(3,4)
X2_1 = abs(3-3) + abs(4-2)#Centroid 1
X2_2 = abs(3-4) + abs(4-8)#Centroid 2

if X2_1 < X2_2:
    print ("X2 is closer to Centroid (3,2)")
else:
    print ("X2 is closer to Centroid (4,8)")
    
#(2,8)
X3_1 = abs(2-3) + abs(8-2)#Centroid 1
X3_2 = abs(2-4) + abs(8-8)#Centroid 2

if X3_1 < X3_2:
    print ("X3 is closer to Centroid (3,2)")
else:
    print ("X3 is closer to Centroid (4,8)")

#(2,3)
X4_1 = abs(2-3) + abs(3-2)#Centroid 1
X4_2 = abs(2-4) + abs(3-8)#Centroid 2

if X4_1 < X4_2:
    print ("X4 is closer to Centroid (3,2)")
else:
    print ("X4 is closer to Centroid (4,8)")
    
#(6,2)
X5_1 = abs(6-3) + abs(2-2)#Centroid 1
X5_2 = abs(6-4) + abs(2-8)#Centroid 2

if X5_1 < X5_2:
    print ("X5 is closer to Centroid (3,2)")
else:
    print ("X5 is closer to Centroid (4,8)")

    
#(6,4)
X6_1 = abs(6-3) + abs(4-2)#Centroid 1
X6_2 = abs(6-4) + abs(4-8)#Centroid 2

if X6_1 < X6_2:
    print ("X6 is closer to Centroid (3,2)")
else:
    print ("X6 is closer to Centroid (4,8)")

    
#(7,3)
X7_1 = abs(7-3) + abs(3-2)#Centroid 1
X7_2 = abs(7-4) + abs(3-8)#Centroid 2

if X7_1 < X7_2:
    print ("X7 is closer to Centroid (3,2)")
else:
    print ("X7 is closer to Centroid (4,8)")  

    
#(7,4)
X8_1 = abs(7-3) + abs(4-2)#Centroid 1
X8_2 = abs(7-4) + abs(4-8)#Centroid 2

if X8_1 < X8_2:
    print ("X8 is closer to Centroid (3,2)")
else:
    print ("X8 is closer to Centroid (4,8)") 
    
#(8,5)
X9_1 = abs(8-3) + abs(5-2)#Centroid 1
X9_2 = abs(8-4) + abs(5-8)#Centroid 2

if X9_1 < X9_2:
    print ("X9 is closer to Centroid (3,2)")
else:
    print ("X9 is closer to Centroid (4,8)") 
    
#(7,6)
X10_1 = abs(7-3) + abs(6-2)#Centroid 1
X10_2 = abs(7-4) + abs(6-8)#Centroid 2

if X10_1 < X10_2:
    print ("X10 is closer to Centroid (3,2)")
else:
    print ("X10 is closer to Centroid (4,8)")
# Out:
# For Part 1:
#
# For each of the win coordinates:
# X1  (3,5)
# X2  (3,4)
# X3  (2,8)
# X4  (2,3)
# X5  (6,2)
# X6  (6,4)
# X7  (7,3)
# X8  (7,4)
# X9  (8,5)
# X10 (7,6)
#
#
#
#
# Part 1 Question 1:
# Using the Manhattan distance metric:
# X1 is closer to Centroid (4,6)
# X2 is closer to Centroid (5,4)
# X3 is closer to Centroid (4,6)
# X4 is closer to Centroid (5,4)
# X5 is closer to Centroid (5,4)
# X6 is closer to Centroid (5,4)
# X7 is closer to Centroid (5,4)
# X8 is closer to Centroid (5,4)
# X9 is closer to Centroid (5,4)
# X10 is closer to Centroid (4,6)
#
#
#
#
# Part 1 Question 2:
# Using the Euclidian distance metric:
# X1 is closer to Centroid (4,6)
# X2 is closer to Centroid (5,4)
# X3 is closer to Centroid (4,6)
# X4 is closer to Centroid (5,4)
# X5 is closer to Centroid (5,4)
# X6 is closer to Centroid (5,4)
# X7 is closer to Centroid (5,4)
# X8 is closer to Centroid (5,4)
# X9 is closer to Centroid (5,4)
# X10 is closer to Centroid (5,4)
#
#
#
#
# Part 1 Question 3:
# ...
